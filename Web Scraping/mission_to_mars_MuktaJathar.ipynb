# %% [markdown]
# # Mission to Mars (Web Scraping)

# %% [markdown]
# Objective is to build a web application that scrapes various websites for data related to the Mission to Mars and displays the information in a single HTML page. Jupyter notebook is used for a part of the process.

# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
from splinter import Browser
import pandas as pd

# %% [markdown]
# ### NASA Mars News
#
# Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. Assign the text to variables that can be referenced later.

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'

# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
result = soup.find('div',class_="slide")

result

#Retrieve article title and paragraph text
    
title = result.find('div',class_="content_title").text
para_text = result.find('div',class_="rollover_description_inner").text
    

print(title)
print(para_text)
# Out:
# NASA Garners 7 Webby Award Nominations
#
#
#
# Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.

# %% [markdown]
# ### JPL Mars Space Images - Featured Image

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
#Using splinter
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

html = browser.html

soup = BeautifulSoup(html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-121-27f21f861e8e> in <module>
#       1 #Using splinter
#       2 executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
# ----> 3 browser = Browser('chrome', **executable_path, headless=False)
#       4
#       5 url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/splinter/browser.py in Browser(driver_name, *args, **kwargs)
#      62     except KeyError:
#      63         raise DriverNotFoundError("No driver for %s" % driver_name)
# ---> 64     return driver(*args, **kwargs)
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/splinter/driver/webdriver/chrome.py in __init__(self, options, user_agent, wait_time, fullscreen, incognito, headless, **kwargs)
#      41             options.add_argument("--disable-gpu")
#      42
# ---> 43         self.driver = Chrome(options=options, **kwargs)
#      44
#      45         self.element_class = WebDriverElement
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /anaconda3/envs/PythonEnv/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# SessionNotCreatedException: Message: session not created: Chrome version must be between 70 and 73
#   (Driver info: chromedriver=73.0.3683.68 (47787ec04b6e38e22703e856e101e840b65afe72),platform=Mac OS X 10.14.3 x86_64)

# %%
result = soup.find_all('a',class_="corousel_items")

results

# part_image_url=result.get('data-fancybox-href') 

# featured_image_url="https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"+part_image_url

# featured_image_url
# Out:
# <div class="slide">
# <div class="image_and_description_container">
# <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
# <div class="rollover_description">
# <div class="rollover_description_inner">
# Nominees include four JPL projects: the solar system and climate websites, InSight social media, and a 360-degree Earth video. Public voting closes April 18, 2019.
# </div>
# <div class="overlay_arrow">
# <img alt="More" src="/assets/overlay-arrow.png"/>
# </div>
# </div>
# <img alt="NASA Garners 7 Webby Award Nominations" class="img-lazy" data-lazy="/system/news_items/list_view_images/8426_Webby2019-320x240.jpg" src="/assets/loading_320x240.png"/>
# </a>
# </div>
# <div class="content_title">
# <a href="/news/8426/nasa-garners-7-webby-award-nominations/">
# NASA Garners 7 Webby Award Nominations
# </a>
# </div>
# </div>

# %% [markdown]
# ### Mars Weather
#
# Visit the Mars Weather twitter account and scrape the latest Mars weather tweet from the page. Save the tweet text for the weather report as a variable called mars_weather.

# %%
url = 'https://mobile.twitter.com/marswxreport?lang=en'

# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.1//EN" "http://www.openmobilealliance.org/tech/DTD/xhtml-mobile11.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <link href="https://twitter.com/marswxreport" rel="canonical"/>
#   <meta content="twitter://user?screen_name=marswxreport" name="twitter-redirect-url"/>
#   <meta content='{"pwreset-iphone":true,"android":true,"email":true}' name="twitter-redirect-srcs"/>
#   <link href="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/favicon.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    Mars Weather (@MarsWxReport) on Twitter
#   </title>
#   <link href="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/assets/a.css" inline="false" media="screen" rel="stylesheet" type="text/css"/>
#   <script src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/javascripts/framebust.js" type="text/javascript">
#   </script>
#   <script async="" defer="" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/javascripts/serviceworker.js" type="text/javascript">
#   </script>
#   <meta content="V0yIS0Ec_o3Ii9KThrCoMCkwTYMMJ_JYx_RSaGhFYvw" name="google-site-verification"/>
#   <meta content='{"m2_mmw_scribe_get_url":true}' name="deciders"/>
#  </head>
#  <body class="images nojs users-page users-show-page">
#   <div id="container">
#    <div id="brand_bar">
#     <table id="top">
#      <tr>
#       <td class="left">
#        <a class="brandmark" href="/">
#         <img alt="Twitter" height="28" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/larry_28px.gif"/>
#        </a>
#       </td>
#       <td class="right">
#        <img alt="|" class="divider" height="28" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/brandbar_divider.gif"/>
#        <a class="search" href="#search">
#         <img alt="Search" height="28" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/search_28px.gif"/>
#        </a>
#        <img alt="|" class="divider" height="28" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/brandbar_divider.gif"/>
#        <a class="signin" href="/session/new">
#         <span>
#          Log in
#         </span>
#        </a>
#        <img alt="|" class="divider" height="28" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/brandbar_divider.gif"/>
#        <a href="/signup">
#         <span class="signup">
#          Sign up
#         </span>
#        </a>
#       </td>
#      </tr>
#     </table>
#    </div>
#    <div id="main_content">
#     <div class="profile">
#      <table class="profile-details">
#       <tr>
#        <td class="avatar">
#         <img alt="Mars Weather" src="https://pbs.twimg.com/profile_images/2552209293/220px-Mars_atmosphere_normal.jpg"/>
#        </td>
#        <td class="user-info">
#         <div class="fullname">
#          Mars Weather
#         </div>
#         <div class="username">
#          <span>
#           @
#          </span>
#          <span class="screen-name">
#           MarsWxReport
#          </span>
#         </div>
#         <div class="location">
#          Gale Crater, Mars
#         </div>
#        </td>
#       </tr>
#       <tr>
#        <td class="details" colspan="2">
#         <div class="bio">
#          <div class="dir-ltr" dir="ltr">
#           Updates as avail from the REMS weather instrument aboard
#           <a class="tweet-url twitter-atreply pretty-link" data-mentioned-user-id="0" dir="ltr" href="/MarsCuriosity" rel="nofollow">
#            @MarsCuriosity
#           </a>
#           .  Data credit: Centro deAstrobiologia, FMI, JPL/NASA, Not an official acct.
#          </div>
#         </div>
#         <div class="url">
#          <div class="dir-ltr">
#           <a class="twitter-timeline-link activeLink dir-ltr tco-link" data-url="mars.nasa.gov/news/8415/insi…" dir="ltr" href="https://t.co/0PMWfPs8cw" rel="nofollow" target="_blank">
#            mars.nasa.gov/news/8415/insi…
#           </a>
#          </div>
#         </div>
#        </td>
#       </tr>
#      </table>
#      <table class="profile-stats">
#       <tr>
#        <td class="stat">
#         <div class="statnum">
#          1,798
#         </div>
#         <div class="statlabel">
#          Tweets
#         </div>
#        </td>
#        <td class="stat">
#         <a href="/MarsWxReport/following">
#          <div class="statnum">
#           53
#          </div>
#          <div class="statlabel">
#           Following
#          </div>
#         </a>
#        </td>
#        <td class="stat stat-last">
#         <a href="/MarsWxReport/followers">
#          <div class="statnum">
#           39,723
#          </div>
#          <div class="statlabel">
#           Followers
#          </div>
#         </a>
#        </td>
#       </tr>
#      </table>
#      <div class="profile-actions">
#       <form action="/i/guest/follow/MarsWxReport" method="post">
#        <span class="m2-auth-token">
#         <input name="authenticity_token" type="hidden" value="a2ca6c64b91dabafbaa68cc4ba84697a6461c635"/>
#        </span>
#        <span class="w-button-common w-button">
#         <input name="commit" type="submit" value="Follow"/>
#        </span>
#       </form>
#       <form action="/MarsWxReport/actions" method="get">
#        <span class="w-button-common w-button">
#         <input name="commit" type="submit" value="•••"/>
#        </span>
#       </form>
#      </div>
#     </div>
#     <div class="w-mediaonebox">
#      <table>
#       <tr>
#        <td style="width: 138px;">
#         <a href="/MarsWxReport/media/grid?idx=0">
#          <img height="78" src="https://pbs.twimg.com/media/D43yPuhW0AEDC_9.jpg:thumb" width="138"/>
#         </a>
#        </td>
#        <td>
#        </td>
#       </tr>
#      </table>
#      <div class="see-more">
#       <a href="/MarsWxReport/media/grid">
#        View more photos
#       </a>
#      </div>
#     </div>
#     <div class="timeline">
#      <table class="titlebar">
#       <tr>
#        <td>
#         Tweets
#        </td>
#        <td class="right fifty">
#         <form action="/MarsWxReport/follow_sms" method="get">
#          <span class="w-button-common w-button-follow-sms-small">
#           <input alt="Follow by SMS" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/notifications_default_sm.gif" type="image"/>
#          </span>
#         </form>
#        </td>
#       </tr>
#      </table>
#      <table class="tweet " href="/MarsWxReport/status/1120818237002981376?p=v">
#       <tr class="tweet-header ">
#        <td class="avatar" rowspan="3">
#         <a href="/MarsWxReport?p=i">
#          <img alt="Mars Weather" src="https://pbs.twimg.com/profile_images/2552209293/220px-Mars_atmosphere_normal.jpg"/>
#         </a>
#        </td>
#        <td class="user-info">
#         <a href="/MarsWxReport?p=s">
#          <strong class="fullname">
#           Mars Weather
#          </strong>
#          <div class="username">
#           <span>
#            @
#           </span>
#           MarsWxReport
#          </div>
#         </a>
#        </td>
#        <td class="timestamp">
#         <a href="/MarsWxReport/status/1120818237002981376?p=p" name="tweet_1120818237002981376">
#          2h
#         </a>
#        </td>
#       </tr>
#       <tr class="tweet-container">
#        <td class="tweet-content" colspan="2">
#         <div class="tweet-text" data-id="1120818237002981376">
#          <div class="dir-ltr" dir="ltr">
#           InSight sol 143 (2019-04-22) low -98.0ºC (-144.3ºF) high -19.8ºC (-3.7ºF)
# winds from the SW at 4.5 m/s (10.1 mph) gusting to 12.1 m/s (27.2 mph)
# pressure at 7.40 hPa
#           <a class="twitter_external_link dir-ltr tco-link has-expanded-path" data-entity-id="1120818234285019137" data-expanded-path="/MarsWxReport/status/1120818237002981376/photo/1" data-pre-embedded="true" data-tco-id="EOazNkJqjD" data-url="https://twitter.com/MarsWxReport/status/1120818237002981376/photo/1" dir="ltr" href="https://t.co/EOazNkJqjD" rel="nofollow" target="_top">
#            pic.twitter.com/EOazNkJqjD
#           </a>
#          </div>
#         </div>
#        </td>
#       </tr>
#       <tr>
#        <td class="meta-and-actions" colspan="2">
#         <span class="metadata">
#          <a href="/MarsWxReport/status/1120818237002981376?p=v">
#           View photo
#          </a>
#          <span class="middot">
#           ·
#          </span>
#         </span>
#         <span class="tweet-actions">
#          <a class="first" href="/MarsWxReport/reply/1120818237002981376?p=r">
#           <img alt="Reply" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_reply.gif"/>
#          </a>
#          <a href="/statuses/1120818237002981376/retweet?p=t">
#           <img alt="Retweet" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_rt.gif"/>
#          </a>
#          <a class="favorite" href="/statuses/1120818237002981376/favorite?p=f&amp;authenticity_token=a2ca6c64b91dabafbaa68cc4ba84697a6461c635">
#           <img alt="Like" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_heart.gif"/>
#          </a>
#          <a class="last" href="/MarsWxReport/status/1120818237002981376/actions">
#          </a>
#         </span>
#        </td>
#       </tr>
#      </table>
#      <table class="tweet " href="/MarsWxReport/status/1120818204039839744?p=v">
#       <tr class="tweet-header ">
#        <td class="avatar" rowspan="3">
#         <a href="/MarsWxReport?p=i">
#          <img alt="Mars Weather" src="https://pbs.twimg.com/profile_images/2552209293/220px-Mars_atmosphere_normal.jpg"/>
#         </a>
#        </td>
#        <td class="user-info">
#         <a href="/MarsWxReport?p=s">
#          <strong class="fullname">
#           Mars Weather
#          </strong>
#          <div class="username">
#           <span>
#            @
#           </span>
#           MarsWxReport
#          </div>
#         </a>
#        </td>
#        <td class="timestamp">
#         <a href="/MarsWxReport/status/1120818204039839744?p=p" name="tweet_1120818204039839744">
#          2h
#         </a>
#        </td>
#       </tr>
#       <tr class="tweet-container">
#        <td class="tweet-content" colspan="2">
#         <div class="tweet-text" data-id="1120818204039839744">
#          <div class="dir-ltr" dir="ltr">
#           InSight sol 142 (2019-04-21) low -97.5ºC (-143.5ºF) high -18.4ºC (-1.2ºF)
# winds from the W at 4.2 m/s (9.3 mph) gusting to 14.8 m/s (33.1 mph)
# pressure at 7.40 hPa
#          </div>
#         </div>
#        </td>
#       </tr>
#       <tr>
#        <td class="meta-and-actions" colspan="2">
#         <span class="metadata">
#          <a href="/MarsWxReport/status/1120818204039839744?p=v">
#           View details
#          </a>
#          <span class="middot">
#           ·
#          </span>
#         </span>
#         <span class="tweet-actions">
#          <a class="first" href="/MarsWxReport/reply/1120818204039839744?p=r">
#           <img alt="Reply" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_reply.gif"/>
#          </a>
#          <a href="/statuses/1120818204039839744/retweet?p=t">
#           <img alt="Retweet" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_rt.gif"/>
#          </a>
#          <a class="favorite" href="/statuses/1120818204039839744/favorite?p=f&amp;authenticity_token=a2ca6c64b91dabafbaa68cc4ba84697a6461c635">
#           <img alt="Like" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_heart.gif"/>
#          </a>
#          <a class="last" href="/MarsWxReport/status/1120818204039839744/actions">
#          </a>
#         </span>
#        </td>
#       </tr>
#      </table>
#      <table class="tweet " href="/NASAInSight/status/1120768743284469760?p=v">
#       <tr class="tweet-content ">
#        <td class="avatar-spacer">
#        </td>
#        <td class="tweet-social-context" colspan="2">
#         <span class="context">
#          Mars Weather retweeted
#         </span>
#        </td>
#       </tr>
#       <tr class="tweet-header ">
#        <td class="avatar" rowspan="3">
#         <a href="/NASAInSight?p=i">
#          <img alt="NASA InSight" src="https://pbs.twimg.com/profile_images/1062801236166987776/VwIfJa9u_normal.jpg"/>
#         </a>
#        </td>
#        <td class="user-info">
#         <a href="/NASAInSight?p=s">
#          <strong class="fullname">
#           NASA InSight
#          </strong>
#          <div class="username">
#           <span>
#            @
#           </span>
#           NASAInSight
#          </div>
#         </a>
#        </td>
#        <td class="timestamp">
#         <a href="/NASAInSight/status/1120768743284469760?p=p" name="tweet_1120768743284469760">
#          5h
#         </a>
#        </td>
#       </tr>
#       <tr class="tweet-container">
#        <td class="tweet-content" colspan="2">
#         <div class="tweet-text" data-id="1120768743284469760">
#          <div class="dir-ltr" dir="ltr">
#           Mars, I hear you. I’ve detected some quiet but distinct shaking on
#           <a class="twitter-hashtag dir-ltr" data-query-source="hashtag_click" dir="ltr" href="/hashtag/Mars?src=hash">
#            #Mars
#           </a>
#           . The faint rumbles appear to have come from the inside of the planet, and are still being studied by my team. Take a listen.👂
#           <a class="twitter_external_link dir-ltr tco-link" data-expanded-url="http://go.nasa.gov/2GCEBtm" data-url="http://go.nasa.gov/2GCEBtm" dir="ltr" href="https://t.co/GxR1xdRx1F" rel="nofollow noopener" target="_blank" title="http://go.nasa.gov/2GCEBtm">
#            go.nasa.gov/2GCEBtm
#           </a>
#           <a class="twitter_external_link dir-ltr tco-link has-expanded-path" data-entity-id="

#           <img alt="Reply" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_reply.gif"/>
#          </a>
#          <a href="/statuses/1114714732492218369/retweet?p=t">
#           <img alt="Retweet" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_rt.gif"/>
#          </a>
#          <a class="favorite" href="/statuses/1114714732492218369/favorite?p=f&amp;authenticity_token=a2ca6c64b91dabafbaa68cc4ba84697a6461c635">
#           <img alt="Like" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_heart.gif"/>
#          </a>
#          <a class="last" href="/MarsWxReport/status/1114714732492218369/actions">
#          </a>
#         </span>
#        </td>
#       </tr>
#      </table>
#      <table class="tweet " href="/NASAJPL/status/1114543717086453760?p=v">
#       <tr class="tweet-content ">
#        <td class="avatar-spacer">
#        </td>
#        <td class="tweet-social-context" colspan="2">
#         <span class="context">
#          Mars Weather retweeted
#         </span>
#        </td>
#       </tr>
#       <tr class="tweet-header ">
#        <td class="avatar" rowspan="3">
#         <a href="/NASAJPL?p=i">
#          <img alt="NASA JPL" src="https://pbs.twimg.com/profile_images/1033103993709322240/m7jGqR6X_normal.jpg"/>
#         </a>
#        </td>
#        <td class="user-info">
#         <a href="/NASAJPL?p=s">
#          <strong class="fullname">
#           NASA JPL
#          </strong>
#          <div class="username">
#           <span>
#            @
#           </span>
#           NASAJPL
#          </div>
#         </a>
#        </td>
#        <td class="timestamp">
#         <a href="/NASAJPL/status/1114543717086453760?p=p" name="tweet_1114543717086453760">
#          Apr 6
#         </a>
#        </td>
#       </tr>
#       <tr class="tweet-container">
#        <td class="tweet-content" colspan="2">
#         <div class="tweet-text" data-id="1114543717086453760">
#          <div class="dir-ltr" dir="ltr">
#           It’s time!
#           <a class="twitter-hashtag dir-ltr" data-query-source="hashtag_click" dir="ltr" href="/hashtag/ExploreJPL?src=hash">
#            #ExploreJPL
#           </a>
#           tickets are AVAILABLE NOW. Tickets are free, but limited, for our annual public event, this year on May 18-19:
#           <a class="twitter_external_link dir-ltr tco-link" data-expanded-url="https://explore.jpl.nasa.gov/" data-url="https://explore.jpl.nasa.gov/" dir="ltr" href="https://t.co/meeLAfxCFq" rel="nofollow noopener" target="_blank" title="https://explore.jpl.nasa.gov/">
#            explore.jpl.nasa.gov
#           </a>
#           <a class="twitter_external_link dir-ltr tco-link has-expanded-path" data-entity-id="1114539305785892865" data-expanded-path="/NASAJPL/status/1114543717086453760/photo/1" data-pre-embedded="true" data-tco-id="sDqzFKqOc7" data-url="https://twitter.com/NASAJPL/status/1114543717086453760/photo/1" dir="ltr" href="https://t.co/sDqzFKqOc7" rel="nofollow" target="_top">
#            pic.twitter.com/sDqzFKqOc7
#           </a>
#          </div>
#         </div>
#        </td>
#       </tr>
#       <tr>
#        <td class="meta-and-actions" colspan="2">
#         <span class="metadata">
#          <a href="/NASAJPL/status/1114543717086453760?p=v">
#           View photo
#          </a>
#          <span class="middot">
#           ·
#          </span>
#         </span>
#         <span class="tweet-actions">
#          <a class="first" href="/NASAJPL/reply/1114543717086453760?p=r&amp;rt_by=MarsWxReport">
#           <img alt="Reply" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_reply.gif"/>
#          </a>
#          <a href="/statuses/1114543717086453760/retweet?p=t">
#           <img alt="Retweet" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_rt.gif"/>
#          </a>
#          <a class="favorite" href="/statuses/1114543717086453760/favorite?p=f&amp;authenticity_token=a2ca6c64b91dabafbaa68cc4ba84697a6461c635">
#           <img alt="Like" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/tweet_heart.gif"/>
#          </a>
#          <a class="last" href="/NASAJPL/status/1114543717086453760/actions">
#          </a>
#         </span>
#        </td>
#       </tr>
#      </table>
#      <div class="w-button-more">
#       <a href="/MarsWxReport?max_id=1114576250704662533">
#        Load older Tweets
#       </a>
#      </div>
#     </div>
#    </div>
#    <div id="footer">
#     <div class="search-fields">
#      <div class="title">
#       <label for="q">
#        Enter a topic, @name, or fullname
#       </label>
#      </div>
#      <form action="/search" class="search-input" method="get">
#       <table>
#        <tr>
#         <td class="value" id="search">
#          <div>
#           <input id="q" name="q" type="text" value=""/>
#          </div>
#         </td>
#         <td class="button">
#          <input name="s" type="hidden" value="typd"/>
#          <input alt="Search" src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/images/sprites/magnifying_glass.gif" type="image"/>
#         </td>
#        </tr>
#       </table>
#      </form>
#     </div>
#     <table class="global-actions">
#      <tr>
#       <td>
#        <a href="/settings">
#         Settings
#        </a>
#       </td>
#       <td>
#        <a href="https://support.twitter.com/">
#         Help
#        </a>
#       </td>
#      </tr>
#     </table>
#     <div class="view-actions">
#      <a href="#top">
#       Back to top
#      </a>
#      ·
#      <a href="/settings/profile_images">
#       Turn images off
#      </a>
#     </div>
#    </div>
#   </div>
#   <script id="scribe-configuration" type="application/json">
#    {"page":"profile"}
#   </script>
#   <script src="https://ma.twimg.com/twitter-mobile/c048144a9803f5a111a729f051b713bc156e8a6a/assets/m2_tweets.js" type="text/javascript">
#   </script>
#   <img height="0" src="/i/anonymize?data=%5B%7B%22integration%22%3A%22ga%22%2C%22ref%22%3A%22%22%2C%22mobileMetricsToken%22%3A%22155606492955402147%22%7D%5D" style="opacity: 0" width="0"/>
#  </body>
# </html>

# %%
# Retrieve the parent div for latest tweet
results = soup.find('div',class_="tweet-text").text.strip()
results
# Out:
# 'InSight sol 143 (2019-04-22) low -98.0ºC (-144.3ºF) high -19.8ºC (-3.7ºF)\nwinds from the SW at 4.5 m/s (10.1 mph) gusting to 12.1 m/s (27.2 mph)\npressure at 7.40 hPa pic.twitter.com/EOazNkJqjD'

# %% [markdown]
# ### Mars Facts
#
# Visit the Mars Facts webpage and use Pandas to scrape the table containing facts about the planet including Diameter, Mass, etc.
# Use Pandas to convert the data to a HTML table string.

# %%
url='https://space-facts.com/mars/'

#use pandas to scrape table and store as a data frame
df_mars_facts = pd.read_html(url)[0]

df_mars_facts.columns=['Fact','Value']

df_mars_facts
# Out:
#                    Fact                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.42 x 10^23 kg (10.7% Earth)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.52 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                  -153 to 20 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
#convert the data to a HTML table string
html_table=df_mars_facts.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Fact</th>\n      <th>Value</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Equatorial Diameter:</td>\n      <td>6,792 km</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Polar Diameter:</td>\n      <td>6,752 km</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Mass:</td>\n      <td>6.42 x 10^23 kg (10.7% Earth)</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Moons:</td>\n      <td>2 (Phobos &amp; Deimos)</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Orbit Distance:</td>\n      <td>227,943,824 km (1.52 AU)</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Orbit Period:</td>\n      <td>687 days (1.9 years)</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Surface Temperature:</td>\n      <td>-153 to 20 °C</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>First Record:</td>\n      <td>2nd millennium BC</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Recorded By:</td>\n      <td>Egyptian astronomers</td>\n    </tr>\n  </tbody>\n</table>'

# %% [markdown]
# ### Mars Hemispheres
#
# Visit the USGS Astrogeology site to obtain high resolution images for each of Mar's hemispheres.
# Save both the image url string for the full resolution hemisphere image, and the Hemisphere title containing the hemisphere name. Use a Python dictionary to store the data using the keys img_url and title.
# Append the dictionary with the image url string and the hemisphere title to a list. This list will contain one dictionary for each hemisphere.

# %%
hemisphere_image_urls = [
    {"title": "Valles Marineris Hemisphere", "img_url": "https://astrogeology.usgs.gov/cache/images/7cf2da4bf549ed01c17f206327be4db7_valles_marineris_enhanced.tif_full.jpg"},
    {"title": "Cerberus Hemisphere", "img_url": "https://astrogeology.usgs.gov/cache/images/cfa62af2557222a02478f1fcd781d445_cerberus_enhanced.tif_full.jpg"},
    {"title": "Schiaparelli Hemisphere", "img_url": "https://astrogeology.usgs.gov/cache/images/3cdd1cbf5e0813bba925c9030d13b62e_schiaparelli_enhanced.tif_full.jpg"},
    {"title": "Syrtis Major Hemisphere", "img_url": "https://astrogeology.usgs.gov/cache/images/ae209b4e408bb6c3e67b6af38168cf28_syrtis_major_enhanced.tif_full.jpg"},
]

# %% [markdown]
# ### Dictionary of all items scraped
